# %% [markdown]
# Word Press Automation

# %%
df
# Out:
#                          Url Name                           Name  \
# 0                       minecraft                      Minecraft
# 1                  clash-of-clans                 Clash of Clans
# 2        poppy-playtime-chapter-1       Poppy Playtime Chapter 1
# 3                     bloons-td-6                    Bloons TD 6
# 4    grand-theft-auto-san-andreas  Grand Theft Auto: San Andreas
# ..                            ...                            ...
# 100              wrestling-empire               Wrestling Empire
# 101           8-ball-pool-mod-apk                    8 Ball Pool
# 102            fr-legends-mod-apk                     FR Legends
# 103              my-success-story               My Success Story
# 104           dragon-ball-legends            Dragon Ball Legends
#
#                         Package Name       Category  \
# 0             com.mojang.minecraftpe      Adventure
# 1         com.supercell.clashofclans       Strategy
# ...

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import UnexpectedAlertPresentException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
from datetime import date
import time

df = pd.read_csv("Data/internal_links_rephrased_521_1755.csv")

def automation(start_index, end_index):

    chrome_options = Options()
    chrome_options.add_experimental_option("detach", True)
    wordPressDriver = webdriver.Chrome(chrome_options=chrome_options)
    wordPressDriver.get("https://iphoneside.com/wp-admin/post-new.php")
    wordPressDriver.find_element_by_id("user_login").send_keys("iphoneside")
    wordPressDriver.find_element_by_id("user_pass").send_keys("r3457557760R")
    wordPressDriver.find_element_by_id("wp-submit").click()
    wordPressDriver.find_element_by_xpath("//button[@aria-label='Close dialog']").click()

    for i in range(start_index, end_index):

        url_name = df["Url Name"][i]
        apk_name = df["Name"][i]
        apk_name = apk_name.encode('ascii', 'ignore').decode('ascii')
        package_name = df["Package Name"][i]
        apk_category = df["Category"][i]
        apk_mod_features = df["MOD Features"][i]
        apk_version = df["Version"][i]
        apk_requires = df["Requires"][i]
        apk_description_tag = df["Description Tags"][i]
        download_apk_name = df["Download Apk Name"][i]
        apk_download_mods_1 = df["Download Apk Mods 1"][i]
        apk_download_mods_2 = df["Download Apk Mods 2"][i]
        apk_download_file_size_1 = df["Download Apk File Size 1"][i]
        apk_download_file_size_2 = df["Download Apk File Size 2"][i]
        apk_download_file_url_1 = df["Download Apk Page Url 1"][i]
        apk_download_file_url_2 = df["Download Apk Page Url 2"][i]

        today = date.today()
        apk_updated_date = today.strftime("%B %d, %Y")

        # if len(apk_download_mods_1.strip().split(" ")) > 1:
        #     apk_download_mod = "MOD"
        # else:
        #     apk_download_mod = "APK"

        try:
            wordPressDriver.find_element_by_id("dlproap_source").clear()
            wordPressDriver.find_element_by_id("dlproap_source").send_keys(package_name)
            wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 50).until(EC.element_to_be_clickable((By.ID, "dlproap_grab_button"))))
            # wordPressDriver.find_element_by_id("dlproap_grab_button").click()
            time.sleep(1)
            wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 1).until(EC.element_to_be_clickable((By.ID, "set-post-thumbnail"))))
        except UnexpectedAlertPresentException:
            print("Cannot grab APK Name = ", apk_name)
            continue
        except:
            print("Continue")

        # wordPressDriver.find_element_by_id("set-post-thumbnail").click()
        # wordPressDriver.find_element_by_id("media-search-input").clear()

        try:
            wordPressDriver.find_element_by_xpath("//button[text()='Set featured image']").click()
        except:
            wordPressDriver.find_element_by_xpath("//button[text()='Featured image']").click()
            wordPressDriver.find_element_by_xpath("//button[text()='Set featured image']").click()
        
        try:
            wordPressDriver.find_element_by_id("media-search-input").clear()
            firstWordOfName = apk_name.replace(" ", "-")
            firstWordOfName = firstWordOfName + "."
            wordPressDriver.find_element_by_id("media-search-input").send_keys(firstWordOfName)
            time.sleep(3)
            print("Link =", "//ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='" + apk_name + "']/div")
            # wordPressDriver.find_element_by_xpath("//ul[@id='__attachments-view-53']/li[@tabindex=0]/div").click()                                
            wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 5).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='attachments ui-sortable ui-sortable-disabled']/li[contains(translate(@aria-label, 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'), translate('" + apk_name + "', 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'))]/div"))))
        except:
            try:
                wordPressDriver.find_element_by_id("media-search-input").clear()
                firstWordOfName = apk_name.split(" ")[0] + "."
                wordPressDriver.find_element_by_id("media-search-input").send_keys(firstWordOfName)
                time.sleep(3)
                # wordPressDriver.find_element_by_xpath("//ul[@id='__attachments-view-53']/li[@tabindex=0]/div").click()
                wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 5).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='attachments ui-sortable ui-sortable-disabled']/li[contains(translate(@aria-label, 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'), translate('" + firstWordOfName + "', 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'))]/div"))))
            except:
                wordPressDriver.find_element_by_id("media-search-input").clear()
                firstWordOfName = apk_name.split(" ")[0]
                wordPressDriver.find_element_by_id("media-search-input").send_keys(firstWordOfName.replace(":", ""))
                time.sleep(3)
                # wordPressDriver.find_element_by_xpath("//ul[@id='__attachments-view-53']/li[@tabindex=0]/div").click()
                try:
                    wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 5).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='attachments ui-sortable ui-sortable-disabled']/li[contains(translate(@aria-label, 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'), translate('" + firstWordOfName + "', 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'))]/div"))))
                except:
                    print("Simple Image = ", apk_name)
                    wordPressDriver.find_element_by_id("media-search-input").clear()
                    wordPressDriver.find_element_by_id("media-search-input").send_keys(firstWordOfName[0:3])
                    wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 5).until(EC.element_to_be_clickable((By.XPATH, "//ul[@class='attachments ui-sortable ui-sortable-disabled']/li[starts-with(translate(@aria-label, 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'), translate('" + firstWordOfName[0:3] + "', 'ABCDEFGHIJKLMNOPQRSTUVWXYZ', 'abcdefghijklmnopqrstuvwxyz'))]/div"))))

        # wordPressDriver.find_element_by_xpath("//button[text()='Set featured image']").click()
        wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 5).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='button media-button button-primary button-large media-button-select']"))))

        # try:
        #     wordPressDriver.find_element_by_id("new-tag-post_tag").clear()
        # except:
        #     wordPressDriver.find_element_by_xpath("//div[@id='tagsdiv-post_tag']//button[3]").click()
        #     wordPressDriver.find_element_by_id("new-tag-post_tag").clear()
        
        # time.sleep(1)

        # try:
        #     wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_xpath("//ul[@id='categorychecklist']//input[@checked='checked']"))
        # except:
        #     continue
        try:
            wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_xpath("//div[@aria-label='Categories']//label[text()='Games']/preceding-sibling::span/input"))
        except:
            wordPressDriver.find_element_by_xpath("//button[text()='Categories']").click()
            time.sleep(0.5)
            wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_xpath("//div[@aria-label='Categories']//label[text()='Games']/preceding-sibling::span/input"))
        try:
            wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_xpath("//div[@aria-label='Categories']//label[text()='" + apk_category + "']/preceding-sibling::span/input"))
        except:
            # wordPressDriver.find_element_by_xpath("//a[@aria-label='View Posts']").click()
            # wordPressDriver.find_element_by_xpath("//a[text()='Categories']").click()
            # wordPressDriver.get("https://iphoneside.com/wp-admin/edit-tags.php?taxonomy=category")
            wordPressDriver.execute_script("window.open('https://iphoneside.com/wp-admin/edit-tags.php?taxonomy=category');")
            wordPressDriver.switch_to.window(wordPressDriver.window_handles[-1])
            time.sleep(2)
            wordPressDriver.find_element_by_id("tag-name").send_keys(apk_category)
            # wordPressDriver.find_element_by_xpath("//button[text()='Add New Category']").click()
            categoryParentSelect = Select(wordPressDriver.find_element_by_id("parent"))
            categoryParentSelect.select_by_visible_text("Games")
            wordPressDriver.find_element_by_id("submit").click()
            time.sleep(1)
            wordPressDriver.quit()
            automation(i)
            # wordPressDriver.find_element_by_xpath("//button[@class='components-button editor-post-taxonomies__hierarchical-terms-submit is-secondary']").click()
        # wordPressDriver.find_element_by_xpath("//ul[@id='categorychecklist']//input[@checked='checked']").click()
        # wordPressDriver.find_element_by_xpath("//ul[@id='categorychecklist']//label[text()=' Apps']/input").click()
        # wordPressDriver.find_element_by_xpath("//ul[@id='categorychecklist']//label[text()=' "+ apk_category +"']/input").click()

        wordPressDriver.find_element_by_xpath("//div[@class='edit-post-visual-editor__post-title-wrapper']/h1").send_keys(apk_name)

        wordPressDriver.find_element_by_xpath("//button[@aria-label='Options']").click()
        time.sleep(0.5)
        wordPressDriver.find_element_by_xpath("//span[text()='Code editor']/parent::button").click()
        time.sleep(0.5)
        wordPressDriver.find_element_by_xpath("//button[@aria-label='Options']").click()
        time.sleep(0.5)
        # print("Text = " + 'document.getElementById("post-content-0").value="' + apk_description_tag + '";')
        # wordPressDriver.execute_script('document.getElementsByClassName("is-root-container block-editor-block-list__layout").value=`' + apk_description_tag + '`;')
        wordPressDriver.find_element_by_id("post-content-0").click()
        wordPressDriver.find_element_by_id("post-content-0").send_keys(apk_description_tag)

        wordPressDriver.find_element_by_xpath("//button[text()='Exit code editor']").click()

        # time.sleep(0.5)
        # try:
        #     wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 50).until(EC.element_to_be_clickable((By.XPATH, "//span[@id='edit-slug-buttons']/button"))))
        # except:
        #     wordPressDriver.find_element_by_id("title").send_keys(Keys.RETURN)
        #     wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 50).until(EC.element_to_be_clickable((By.XPATH, "//span[@id='edit-slug-buttons']/button"))))
        # # wordPressDriver.find_element_by_xpath("//span[@id='edit-slug-buttons']/button").click()
        # time.sleep(0.5)
        # wordPressDriver.find_element_by_id("new-post-slug").clear()
        # wordPressDriver.find_element_by_id("new-post-slug").send_keys(url_name)
        # time.sleep(0.5)
        # wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 50).until(EC.element_to_be_clickable((By.XPATH, "//span[@id='edit-slug-buttons']/button"))))
        # wordPressDriver.find_element_by_xpath("//span[@id='edit-slug-buttons']/button").click()

        time.sleep(0.5)

        wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_id('dlpro-meta-infosettings-tab'))

        wordPressDriver.find_element_by_xpath("//input[@id='opsi-AppName']").clear()
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-AppName']").send_keys(apk_name)
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-genres']").clear()
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-genres']").send_keys(apk_category)
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-updated']").clear()
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-updated']").send_keys(apk_updated_date)
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-version']").clear()
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-version']").send_keys(apk_version)
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-filesize']").clear()
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-filesize']").send_keys(apk_download_file_size_1)
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-requires']").clear()
        wordPressDriver.find_element_by_xpath("//input[@id='opsi-requires']").send_keys(apk_requires.replace("Android ", ""))

        # wordPressDriver.find_element_by_id("dlpro-meta-modsettings-tab").click()
        wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_id('dlpro-meta-modsettings-tab'))
        time.sleep(1)
        try:
            wordPressDriver.switch_to.frame(wordPressDriver.find_element_by_xpath(xpath="//iframe[@id='DLPRO_mods_ifr']"))
            wordPressDriver.find_element_by_xpath("//p").send_keys(apk_mod_features)

            wordPressDriver.switch_to.default_content()

        except:
            wordPressDriver.find_element_by_xpath("//textarea[@id='DLPRO_mods']").send_keys(apk_mod_features)

        wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_id('dlpro-meta-gallerysetting-tab'))
        poster = wordPressDriver.find_element_by_id("opsi-posters").get_attribute("value").replace("=s300-tmp.png", "")
        wordPressDriver.find_element_by_id("opsi-posters").clear()
        wordPressDriver.find_element_by_id("opsi-posters").send_keys(poster)

        wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_id('dlpro-meta-downloadsetting-tab'))
        wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_xpath("//a[text()='Add More link']"))
        
        if apk_download_file_url_2 == "None":
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_title[]']").clear()
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_title[]']").send_keys(download_apk_name)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_version[]']").send_keys(apk_version)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_types[]']").send_keys(apk_download_mods_1)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_size[]']").send_keys(apk_download_file_size_1)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_url[]']").clear()
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_url[]']").send_keys("https://dl.apkzara.com/")
        else:
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_title[]']").clear()
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_title[]']").send_keys(download_apk_name)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_version[]']").send_keys(apk_version)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_types[]']").send_keys(apk_download_mods_1)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_size[]']").send_keys(apk_download_file_size_1)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_url[]']").clear()
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[1]//input[@name='exthemes_dlbutton_item_url[]']").send_keys("https://dl.apkzara.com/")
            wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_xpath("//a[text()='Add More link']"))
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_title[]']").clear()
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_title[]']").send_keys(download_apk_name)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_version[]']").send_keys(apk_version)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_types[]']").send_keys(apk_download_mods_2)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_size[]']").send_keys(apk_download_file_size_2)
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_url[]']").clear()
            wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']/tbody//tr[2]//input[@name='exthemes_dlbutton_item_url[]']").send_keys("https://dl.apkzara.com/")

        wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[text()='Publish']"))))
        time.sleep(1)
        wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='components-button editor-post-publish-button editor-post-publish-button__button is-primary']"))))
        time.sleep(2)
        wordPressDriver.get("https://iphoneside.com/wp-admin/post-new.php")
        time.sleep(1)

automation(393, 500)
# Out:
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='The House of Da Vinci 2']/div
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='DragnBoom']/div
# Simple Image =  DragnBoom
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='Action Taimanin']/div
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='Killer Bean Unleashed']/div
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='Ocean Is Home: Survival Island']/div
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='Unkilled']/div
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='Russian Car Drift']/div
# Continue
# Link = //ul[@class='attachments ui-sortable ui-sortable-disabled']/li[@aria-label='Airline Commander']/div
# ...

# %%
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
wordPressDriver = webdriver.Chrome(chrome_options=chrome_options)
wordPressDriver.get("https://iphoneside.com/wp-admin/edit.php?ac-actions-form=1&orderby=date&order=asc&s&post_status=all&post_type=post&m=0&cat=53&layout=61bf07e793d3f&filter_action=Filter&action=-1&action2=-1&paged=1")
wordPressDriver.find_element_by_id("user_login").send_keys("iphoneside")
wordPressDriver.find_element_by_id("user_pass").send_keys("r3457557760R")
wordPressDriver.find_element_by_id("wp-submit").click()
categoryParentSelect = Select(wordPressDriver.find_element_by_id("cat"))
categoryParentSelect.select_by_visible_text("Apps")
wordPressDriver.find_element_by_id("post-query-submit").click()

for j in range(2, 4):
    wordPressDriver.get("https://iphoneside.com/wp-admin/edit.php?ac-actions-form=1&orderby=date&order=asc&s&post_status=all&post_type=post&m=0&cat=53&layout=61bf07e793d3f&filter_action=Filter&action=-1&action2=-1&paged=" + str(j))
    action = ActionChains(wordPressDriver)
    tempList = wordPressDriver.find_elements_by_xpath("//tbody[@id='the-list']//tr")
    
    for i in range(len(tempList)):
        wordPressDriver.get("https://iphoneside.com/wp-admin/edit.php?ac-actions-form=1&orderby=date&order=asc&s&post_status=all&post_type=post&m=0&cat=53&layout=61bf07e793d3f&filter_action=Filter&action=-1&action2=-1&paged=" + str(j))
        action = ActionChains(wordPressDriver)
        title = wordPressDriver.find_element_by_xpath("//tbody[@id='the-list']//tr["+ str(i+1) +"]//td[@data-colname='Title']//strong/a").text
        print("Title = ", title)
        try:
            row = df.loc[df["Name"] == title]["Download Apk URL"]
            apkURL = row.values[0]
        except:
            tempTitle = title.replace("à", "Ã ").replace("∞", "").replace("é", "Ã©")
            print("Temp Title = ", tempTitle)
            row = df.loc[df["Name"].str.contains(tempTitle)]["Name"]
            apkURL = row.values[0]
        
        action.move_to_element(wordPressDriver.find_element_by_xpath("//tbody[@id='the-list']//tr["+ str(i+1) +"]")).perform()
        wordPressDriver.find_element_by_xpath("//tbody[@id='the-list']//tr["+ str(i+1) +"]/td[1]//span[@class='edit']/a").click()

        wordPressDriver.execute_script("arguments[0].click();", wordPressDriver.find_element_by_id('dlpro-meta-downloadsetting-tab'))
        wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']//tbody/tr[1]//input[@name='exthemes_dlbutton_item_url[]']").clear()
        wordPressDriver.find_element_by_xpath("//table[@id='dlpro-dlbutton-item']//tbody/tr[1]//input[@name='exthemes_dlbutton_item_url[]']").send_keys(apkURL)
        
        wordPressDriver.execute_script("arguments[0].click();", WebDriverWait(wordPressDriver, 10).until(EC.element_to_be_clickable((By.ID, "publish"))))
# Out:
# C:\Users\Saad\anaconda3\envs\iphoneside\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: use options instead of chrome_options
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Saad\anaconda3\envs\iphoneside\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   """
# C:\Users\Saad\anaconda3\envs\iphoneside\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# C:\Users\Saad\anaconda3\envs\iphoneside\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   import sys
# C:\Users\Saad\anaconda3\envs\iphoneside\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# ...
